# %% [markdown]
# # Extracting and Transforming Metadata

# %%
import csv
import json

# for working with local files
import glob
import os
from os.path import join

# %% [markdown]
# ## LOC Items

# %%
current_loc = os.getcwd()

print(current_loc)
# Out:
# c:\Users\abbys\OneDrive\Desktop\si-676\assignment-1

# %%
metadata_file_path = os.path.join('loc-item-metadata')

print(metadata_file_path)
# Out:
# loc-item-metadata

# %%
# check for right metadata files
file_count = 0
for file in glob.glob('loc-item-metadata\\*.json'):
    file_count += 1
    print(file)

print('found', file_count, 'files')
# Out:
# loc-item-metadata\cph-3g08479.json
# loc-item-metadata\cph-3g10372.json
# loc-item-metadata\cph-3g10434.json
# loc-item-metadata\cph-3g10521.json
# loc-item-metadata\cph-3g10539.json
# loc-item-metadata\jpd-00046.json
# loc-item-metadata\jpd-00139.json
# loc-item-metadata\jpd-00154.json
# loc-item-metadata\jpd-00181.json
# loc-item-metadata\jpd-00278.json
# loc-item-metadata\jpd-00501.json
# loc-item-metadata\jpd-00507.json
# loc-item-metadata\jpd-00790.json
# loc-item-metadata\jpd-01197.json
# loc-item-metadata\jpd-01271.json
# loc-item-metadata\jpd-01307.json
# loc-item-metadata\jpd-01317.json
# loc-item-metadata\jpd-01328.json
# loc-item-metadata\jpd-01361.json
# loc-item-metadata\jpd-01581.json
# loc-item-metadata\jpd-01803.json
# loc-item-metadata\jpd-01822.json
# loc-item-metadata\jpd-02015.json
# loc-item-metadata\jpd-02148.json
# loc-item-metadata\jpd-02457.json
# loc-item-metadata\jpd-02467.json
# loc-item-metadata\jpd-02608.json
# loc-item-metadata\jpd-02925.json
# found 28 files

# %%
# add metadata files to list
list_of_item_metadata_files = list() 
for file in glob.glob('loc-item-metadata\\*.json'):
    list_of_item_metadata_files.append(file)

len(list_of_item_metadata_files)
# Out:
# 28

# %%
# quick duplicate check
list_of_item_metadata_files.sort()

for file in list_of_item_metadata_files:
    print(file)
# Out:
# loc-item-metadata\cph-3g08479.json
# loc-item-metadata\cph-3g10372.json
# loc-item-metadata\cph-3g10434.json
# loc-item-metadata\cph-3g10521.json
# loc-item-metadata\cph-3g10539.json
# loc-item-metadata\jpd-00046.json
# loc-item-metadata\jpd-00139.json
# loc-item-metadata\jpd-00154.json
# loc-item-metadata\jpd-00181.json
# loc-item-metadata\jpd-00278.json
# loc-item-metadata\jpd-00501.json
# loc-item-metadata\jpd-00507.json
# loc-item-metadata\jpd-00790.json
# loc-item-metadata\jpd-01197.json
# loc-item-metadata\jpd-01271.json
# loc-item-metadata\jpd-01307.json
# loc-item-metadata\jpd-01317.json
# loc-item-metadata\jpd-01328.json
# loc-item-metadata\jpd-01361.json
# loc-item-metadata\jpd-01581.json
# loc-item-metadata\jpd-01803.json
# loc-item-metadata\jpd-01822.json
# loc-item-metadata\jpd-02015.json
# loc-item-metadata\jpd-02148.json
# loc-item-metadata\jpd-02457.json
# loc-item-metadata\jpd-02467.json
# loc-item-metadata\jpd-02608.json
# loc-item-metadata\jpd-02925.json

# %%
# set up the containers to create the csv of all the item fields
# file for csv to read out
collection_info_csv = 'collection_items_data.csv'
file_count = 0
items_written = 0
error_count = 0

# set up a list for the columns in your csv; 
# your goal should be to automate this, but . . . 
# it works for demonstration as you set up the crosswalk
headers = ['item_type', 'date_uploaded', 'source_file', 'item_id', 'title', 'genre', 'source', 'date', 'place_of_origin', 'subject', 'item_format', 'language', 'contributor', 'rights', 'alternative_title']

for file in list_of_item_metadata_files:
    file_count += 1
    print('opening', file)

    # try first with one file
    with open(file, 'r', encoding='utf-8') as data:
         # load the item data
        try:
            item_data = json.load(data)
        except:
            print('error loading',file)
            error_count += 1
            continue

        starting_point = item_data['item']['item']
        
         # extract/name the data you want
        # item type
        try:
            item_type = starting_point['format']
        except:
            item_type = starting_point['formats']
        # date uplaoded
        date_uploaded = '2024-12-08'

        # extract the data you want
        # for checking purposes, add in the source of the info
        source_file = str(file)
        # make sure there's some unique and stable identifier
        try:
            item_id = item_data['item']['library_of_congress_control_number']
        except:
            item_id = item_data['item']['url'].split('/')[-2]


        title = starting_point['title']
        genre = starting_point['genre']
        source = item_data['item']['url']
        date = starting_point['date']
        try:
            place_of_origin = starting_point['location']
        except:
            place_of_origin = 'Not found'
        try:
            subject = starting_point['subjects']
        except:
            subject = 'Not found'
        try:
            item_format = starting_point['medium']
        except:
            item_format = 'Not found'
        try:
            language = starting_point['language']
        except:
            language = 'Not found'
        try:
            contributor = starting_point['contributors']
        except:
            contributor = 'Not found'
        try:
            rights = starting_point['rights_information']
        except:
            rights = 'Undetermined'
        try:
            alternative_title = starting_point['other_title']
        except:
            alternative_title = 'Not found'

        # dictionary for the rows
        row_dict = dict()
        
        # look for the item metadata, assign it to the dictionary; 
        # start with some basic elements likely (already enumerated in the headers list) :
        # source file
        row_dict['item_type'] = item_type
        row_dict['date_uploaded'] = date_uploaded
        row_dict['source_file'] = source_file
        # identifier
        row_dict['item_id'] = item_id
        # title
        row_dict['title'] = title
        # genre
        row_dict['genre'] = genre
        # link
        row_dict['source'] = source
        # date
        row_dict['date'] = date
        # place of origin
        row_dict['place_of_origin'] = place_of_origin
        # subject
        row_dict['subject'] = subject
        # format
        row_dict['item_format'] = item_format
        # language
        row_dict['language'] = language
        # contributor
        row_dict['contributor'] = contributor
        #rights
        row_dict['rights'] = rights 
        # alt title
        row_dict['alternative_title'] = alternative_title
        
        print('created row dictionary:',row_dict)

    # write to the csv
    with open(collection_info_csv, 'a', encoding='utf-8', newline='') as fout:
        writer = csv.DictWriter(fout, fieldnames=headers)
        if items_written == 0:
            writer.writeheader()
        writer.writerow(row_dict)
        items_written += 1
        print('adding',item_id)

print('\n\n--- LOG ---')
print('wrote',collection_info_csv)
print('with',items_written,'items')
print(error_count,'errors (info not written)')
# Out:
# opening loc-item-metadata\cph-3g08479.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\cph-3g08479.json', 'item_id': '2002700239', 'title': 'Gokakoku ... gankirō ni oite sakamori no zu', 'genre': ['Triptychs--Japanese--1860', 'Woodcuts--Japanese--Color--1860'], 'source': 'https://www.loc.gov/item/2002700239/', 'date': '1860.', 'place_of_origin': ['Japan--Yokohama-shi'], 'subject': ['Foreign visitors--Japan--Yokohama-shi--1860', 'Entertainment--Japan--Yokohama-shi--1860', 'Courtesans--Japan--Yokohama-shi--1860', 'Eating & drinking--Japan--Yokohama-shi--1860', 'Teahouses--Japan--Yokohama-shi--1860-1870'], 'item_format': ['1 print on hōsho paper (3 sheets) : woodcut, color ; 36.5 x 24.5 cm. (each block), 37 x 24.8 cm. (each sheet)'], 'language': ['jpn'], 'contributor': ['Ochiai, Yoshiiku, 1833-1904, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Five nations - merrymaking at the Gankirō tea house.']}
# adding 2002700239
# opening loc-item-metadata\cph-3g10372.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\cph-3g10372.json', 'item_id': '2002700113', 'title': '[Village scene in Japan showing people engaged in various activities]', 'genre': ['Woodcuts--Japanese--Color--1860-1880'], 'source': 'https://www.loc.gov/item/2002700113/', 'date': '[ca. 1870]', 'place_of_origin': ['Japan'], 'subject': ['City & town life--Japan--1860-1880', 'Rickshaws--Japan--1860-1880', 'Horseback riding--Japan--1860-1880', 'Boats--Japan--1860-1880', 'Farming--Japan--1860-1880', 'Conversation--1860-1880'], 'item_format': ['1 print on hōsho paper : woodcut, color ; 35 x 23 cm. (block), 35.6 x 23 cm. (sheet)'], 'language': ['jpn'], 'contributor': 'Not found', 'rights': 'No known restrictions on publication.', 'alternative_title': 'Not found'}
# adding 2002700113
# opening loc-item-metadata\cph-3g10434.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\cph-3g10434.json', 'item_id': '2002700173', 'title': 'Ueno kōen naikoku kangyō daini hakurankai bijutsukan narabini [shojo] funsuiki no zu', 'genre': ['Woodcuts--Japanese--Color--1880-1890', 'Triptychs--Japanese--Color--1880-1890'], 'source': 'https://www.loc.gov/item/2002700173/', 'date': '1881.', 'place_of_origin': ['Japan--Tokyo', 'Ueno Kōen (Tokyo, Japan)'], 'subject': ['Exhibitions--Japan--Tokyo--1880-1890', 'People--Japan--Tokyo--1880-1890', 'Fountains--Japan--Tokyo--1880-1890', 'Ueno Kōen (Tokyo, Japan)'], 'item_format': ['1 print on hōsho paper (3 sheets) : woodcut, color ; each block 36.2 x 24.2 cm., each sheet 37.5 x 25 cm.'], 'language': ['jpn'], 'contributor': ['Utagawa, Hiroshige, 1842?-1894, artist, engraver.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Second national industrial exhibition at Ueno Park.']}
# adding 2002700173
# opening loc-item-metadata\cph-3g10521.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\cph-3g10521.json', 'item_id': '2002700238', 'title': 'Amerikajin yūgyō', 'genre': ['Woodcuts--Japanese--Color--1860-1870'], 'source': 'https://www.loc.gov/item/2002700238/', 'date': '[186-]', 'place_of_origin': ['Japan'], 'subject': ['Foreign visitors--American--Japan--1860-1870', 'Families--Japan--1860-1870', 'Walking--Japan--1860-1870', 'Recreation--Japan--1860-1870'], 'item_format': ['1 print on hōsho paper : woodcut, color ; 35.5 x 24.2 cm. (block), 37.5 x 25.2 cm. (sheet)'], 'language': ['jpn'], 'contributor': ['Utagawa, Yoshifuji, 1828-1887, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Americans taking a stroll.']}
# adding 2002700238
# opening loc-item-metadata\cph-3g10539.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\cph-3g10539.json', 'item_id': '2002700255', 'title': 'Amerikakoku jōkisenchū no zu', 'genre': ['Triptychs--Japanese--1860-1870', 'Woodcuts--Japanese--Color--1860-1870'], 'source': 'https://www.loc.gov/item/2002700255/', 'date': '1861.', 'place_of_origin': ['Japan'], 'subject': ['Dining rooms--Japan--1860-1870', 'Passenger quarters--1860-1870', 'Eating & drinking--Japan--1860-1870', 'Ships--American--Japan--1860-1870'], 'item_format': ['1 print on hōsho paper (3 sheets) : woodcut, color ; 35.9 x 24.4 cm. (each block), 37.2 x 25.6 cm. (each sheet)'], 'language': ['jpn'], 'contributor': ['Utagawa, Yoshikazu, active 1848-1863, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Interior of an American steamship.']}
# adding 2002700255
# opening loc-item-metadata\jpd-00046.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00046.json', 'item_id': '2009615043', 'title': 'Koishikawa yuki no ashita', 'genre': ['Landscape prints--1830-1840', 'Ukiyo-e--Japanese--1830-1840', 'Woodcuts--Japanese--Color--1830-1840'], 'source': 'https://www.loc.gov/item/2009615043/', 'date': '[1832 or 1833]', 'place_of_origin': ['Japan'], 'subject': ['Snow--Japan--1830-1840', 'Winter--Japan--1830-1840'], 'item_format': ['1 print : woodcut, color ; 25.3 x 37.4 cm.'], 'language': ['jpn'], 'contributor': ['Katsushika, Hokusai, 1760-1849, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Snow at Koishikawa.']}
# adding 2009615043
# opening loc-item-metadata\jpd-00139.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00139.json', 'item_id': '2009615132', 'title': 'Semitori', 'genre': ['Ukiyo-e--Japanese--1760-1770', 'Woodcuts--Japanese--Color--1760-1770'], 'source': 'https://www.loc.gov/item/2009615132/', 'date': '1765.', 'place_of_origin': ['Japan'], 'subject': ['Women--Domestic life--Japan--1760-1770', 'Children--Japan--1760-1770', 'Recreation--Japan--1760-1770', 'Crickets--Japan--1760-1770'], 'item_format': ['1 print : woodcut, color ; 27.7 x 19.1 cm.'], 'language': ['jpn'], 'contributor': ['Suzuki, Harunobu, 1725?-1770, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Catching crickets.']}
# adding 2009615132
# opening loc-item-metadata\jpd-00154.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00154.json', 'item_id': '2009615185', 'title': 'Hanami zuki', 'genre': ['Ukiyo-e--Japanese--1780-1790', 'Woodcuts--Japanese--Color--1780-1790'], 'source': 'https://www.loc.gov/item/2009615185/', 'date': '[between 1785 and 1789]', 'place_of_origin': ['Japan'], 'subject': ['Cherry trees--Japan--1780-1790', 'Women--Social life--Japan--1780-1790', 'Courtesans--Japan--1780-1790', 'Red-light districts--Japan--1780-1790'], 'item_format': ['1 print : woodcut, color ; 22.4 x 15.9 cm.'], 'language': ['jpn'], 'contributor': ['Torii, Kiyonaga, 1752-1815, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Cherry blossom viewing month.']}
# adding 2009615185
# opening loc-item-metadata\jpd-00181.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00181.json', 'item_id': '2009615173', 'title': 'Kanbara', 'genre': ['Ukiyo-e--Japanese--1850-1860', 'Woodcuts--Japanese--Color--1850-1860'], 'source': 'https://www.loc.gov/item/2009615173/', 'date': '[ca. 1855]', 'place_of_origin': ['Japan', 'Tōkaidō (Japan)', 'Fuji, Mount (Japan)'], 'subject': ['Pilgrimages--Japan--1850-1860', 'Pilgrims--Japan--1850-1860', 'Teahouses--Japan--1850-1860', 'Tōkaidō (Japan)', 'Fuji, Mount (Japan)'], 'item_format': ['1 print : woodcut, color ; 36 x 24.7 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': 'Not found'}
# adding 2009615173
# opening loc-item-metadata\jpd-00278.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00278.json', 'item_id': '2009615268', 'title': 'Higashi no kata Arakuma', 'genre': ['Portrait prints--1840-1850', 'Ukiyo-e--Japanese--1840-1850', 'Woodcuts--Japanese--Color--1840-1850'], 'source': 'https://www.loc.gov/item/2009615268/', 'date': '[ca. 1847]', 'place_of_origin': ['Japan'], 'subject': ['Sumo wrestlers--Japan--1840-1850'], 'item_format': ['1 print : woodcut, color ; 38.3 x 25.7 cm.'], 'language': ['jpn'], 'contributor': ['Utagawa, Kunisada, 1786-1864, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['The wrestler Arakuma of the East Side.']}
# adding 2009615268
# opening loc-item-metadata\jpd-00501.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00501.json', 'item_id': '2009615472', 'title': 'Sumida tsutsumi hanami no zu', 'genre': ['Ukiyo-e--Japanese--1840-1860', 'Woodcuts--Japanese--Color--1840-1860'], 'source': 'https://www.loc.gov/item/2009615472/', 'date': '[between 1848 and 1854]', 'place_of_origin': ['Japan', 'Sumida River (Japan)'], 'subject': ['Sightseers--Japan--1840-1860', 'Cherry trees--Japan--1840-1860', 'Flowers--Japan--1840-1860', 'Rivers--Japan--1840-1860', 'Sumida River (Japan)'], 'item_format': ['1 print : woodcut, color ; 24.4 x 37 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Viewing cherry blossoms along the Sumida River.']}
# adding 2009615472
# opening loc-item-metadata\jpd-00507.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00507.json', 'item_id': '2009615477', 'title': 'Sakura namiki zu', 'genre': ['Landscape prints--1820-1860', 'Ukiyo-e--Japanese--1820-1860', 'Woodcuts--Japanese--Color--1820-1860--Reproductions--1890-1920'], 'source': 'https://www.loc.gov/item/2009615477/', 'date': '[between 1820 and 1858, printed later]', 'place_of_origin': ['Japan'], 'subject': ['Cherry trees--Japan--1820-1860', 'Flowers--Japan--1820-1860'], 'item_format': ['1 print : woodcut, color ; 25.5 x 37.7 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['A Grove of Cherry Trees.']}
# adding 2009615477
# opening loc-item-metadata\jpd-00790.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-00790.json', 'item_id': '2008660052', 'title': 'Hagi', 'genre': ['Ukiyo-e--1800-1810', 'Woodcuts--Japanese--Color--1800-1810'], 'source': 'https://www.loc.gov/item/2008660052/', 'date': '1809.', 'place_of_origin': ['Japan'], 'subject': ['Women--Clothing & dress--Japan--1800-1810', 'Shrubs--Japan--1800-1810', 'Poets--Japan--1800-1810'], 'item_format': ['1 print : woodcut, color ; 37.6 x 26.4 cm.'], 'language': ['jpn'], 'contributor': ['Utagawa, Toyokuni, 1769-1825, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Bushclover.']}
# adding 2008660052
# opening loc-item-metadata\jpd-01197.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01197.json', 'item_id': '2009630236', 'title': 'Sakura cherry', 'genre': ['Ink drawings--Japanese--Color--1870-1880'], 'source': 'https://www.loc.gov/item/2009630236/', 'date': '[187-]', 'place_of_origin': ['Japan'], 'subject': ['Flowers--Japan--1870-1880', 'Cherry trees--Japan--1870-1880', 'Leaves--1870-1880'], 'item_format': ['1 drawing : ink, color ; 14 x 9.7 cm (sheet)'], 'language': ['eng'], 'contributor': 'Not found', 'rights': 'No known restrictions on publication.', 'alternative_title': 'Not found'}
# adding 2009630236
# opening loc-item-metadata\jpd-01271.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01271.json', 'item_id': '2005675751', 'title': 'Tanba kanesaka', 'genre': ['Ukiyo-e--1850-1860', 'Landscape prints--Japanese--1850-1860', 'Woodcuts--Color--Japanese--1850-1860'], 'source': 'https://www.loc.gov/item/2005675751/', 'date': '1853]', 'place_of_origin': ['Japan--Tanba Region'], 'subject': ['Rock formations--Japan--Tanba Region--1850-1860'], 'item_format': ['1 print : woodcut, color ; 35.9 x 24.1 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Kanesaka of Tanba.']}
# adding 2005675751
# opening loc-item-metadata\jpd-01307.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01307.json', 'item_id': '2004666335', 'title': 'Tōto meguro yuhhigaoka', 'genre': ['Ukiyo-e--1850-1860', 'Landscape prints--Japanese--1850-1860', 'Woodcuts--Color--Japanese--1850-1860'], 'source': 'https://www.loc.gov/item/2004666335/', 'date': '1858.', 'place_of_origin': ['Japan--Tokyo', 'Fuji, Mount (Japan)'], 'subject': ['Maples--Japan--Tokyo--1850-1860', 'Fuji, Mount (Japan)--1850-1860'], 'item_format': ['1 print : woodcut, color ; 35.8 x 24.6 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Sunset Hill, Meguro in the eastern capitol.']}
# adding 2004666335
# opening loc-item-metadata\jpd-01317.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01317.json', 'item_id': '2004666330', 'title': 'Suruga miho no matsubara', 'genre': ['Ukiyo-e--1850-1860', 'Landscape prints--Japanese--1850-1860', 'Woodcuts--Color--Japanese--1850-1860'], 'source': 'https://www.loc.gov/item/2004666330/', 'date': '1858.', 'place_of_origin': ['Japan', 'Fuji, Mount (Japan)', 'Suruga Bay (Japan)'], 'subject': ['Sailboats--Japanese--Japan--1850-1860', 'Fuji, Mount (Japan)--1850-1860', 'Suruga Bay (Japan)--1850-1860'], 'item_format': ['1 print : woodcut, color ; 36 x 24.6 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Pine beach at Miho in Suruga.']}
# adding 2004666330
# opening loc-item-metadata\jpd-01328.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01328.json', 'item_id': '2008660269', 'title': 'Tamagawa-zutsumi no hana', 'genre': ['Ukiyo-e--Japanese--Color--1850-1860', 'Woodcuts--Japanese--Color--1850-1860'], 'source': 'https://www.loc.gov/item/2008660269/', 'date': '1856.', 'place_of_origin': ['Japan'], 'subject': ['Cherry trees--Japan--1850-1860', 'Flowers--Japan--1850-1860', 'Rivers--Japan--1850-1860', 'Sightseers--Japan--1850-1860'], 'item_format': ['1 print : woodcut, color ; 36.3 x 24.4 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Blossoms on the Tama River embankment.']}
# adding 2008660269
# opening loc-item-metadata\jpd-01361.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01361.json', 'item_id': '2008660302', 'title': 'Yamato hasedera', 'genre': ["Bird's-eye view prints--1850-1860", 'Ukiyo-e--Japanese--Color--1850-1860', 'Woodcuts--Japanese--Color--1850-1860'], 'source': 'https://www.loc.gov/item/2008660302/', 'date': '1859.', 'place_of_origin': ['Japan'], 'subject': ['Buddhist temples--Japan--1850-1860', 'Wooden buildings--Japan--1850-1860', 'Flowers--Japan--1850-1860'], 'item_format': ['1 print : woodcut, color ; 35.7 x 23.8 cm.'], 'language': ['jpn'], 'contributor': ['Utagawa, Hiroshige, 1826-1869, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Hasedera in Yamato Province.']}
# adding 2008660302
# opening loc-item-metadata\jpd-01581.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01581.json', 'item_id': '2002700010', 'title': 'Zoushigaya fujimi chaya', 'genre': ['Ukiyo-e--1850-1860', 'Landscape prints--Japanese--1850-1860', 'Woodcuts--Japanese--Color--1850-1860'], 'source': 'https://www.loc.gov/item/2002700010/', 'date': '1858.', 'place_of_origin': ['Japan', 'Fuji, Mount (Japan)'], 'subject': ['Teahouses--Japan--1850-1860', 'Fuji, Mount (Japan)--1850-1860'], 'item_format': ['1 print : woodcut, color ; 35.9 x 24.5 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Fujimi Teahouse at Zoshigaya.']}
# adding 2002700010
# opening loc-item-metadata\jpd-01803.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01803.json', 'item_id': '2008660497', 'title': '[Fūkeiga]', 'genre': ['Landscapes (Representations)--Japanese--1830-1860', 'Ukiyo-e--Japanese--Color--1830-1860--Reproductions--1900-1940', 'Woodcuts--Japanese--Color--1830-1860--Reproductions--1900-1940'], 'source': 'https://www.loc.gov/item/2008660497/', 'date': '[between 1900 and 1940, from an earlier print]', 'place_of_origin': ['Japan'], 'subject': ['Rice paddies--Japan--1830-1860', 'Rain--Japan--1830-1860'], 'item_format': ['1 print : woodcut, color.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['[Rice planting in rain].']}
# adding 2008660497
# opening loc-item-metadata\jpd-01822.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-01822.json', 'item_id': '2008660517', 'title': '[Fūkeiga]', 'genre': ['Landscapes (Representations)--Japanese--1830-1860', 'Ukiyo-e--Japanese--Color--1830-1860', 'Woodcuts--Japanese--Color--1830-1860--Reproductions--1900-1940'], 'source': 'https://www.loc.gov/item/2008660517/', 'date': '[between 1900 and 1940, from an earlier print]', 'place_of_origin': ['Japan'], 'subject': ['Moon--1830-1860', 'Moonlight--Japan--1830-1860', 'Night--Japan--1830-1860', 'Boats--Japan--1830-1860'], 'item_format': ['1 print : woodcut, color.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': 'Not found'}
# adding 2008660517
# opening loc-item-metadata\jpd-02015.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-02015.json', 'item_id': '2008660635', 'title': 'Koganeibashi no sekishō', 'genre': ['Ukiyo-e--Japanese--Color--1830-1840', 'Woodcuts--Japanese--Color--1830-1840--Reproductions--1890-1940'], 'source': 'https://www.loc.gov/item/2008660635/', 'date': '[1838, printed later]', 'place_of_origin': ['Japan', 'Fuji, Mount (Japan)'], 'subject': ['Bridges--Japan--1830-1840', 'Cherry trees--Japan--1830-1840', 'Flowers--Japan--1830-1840', 'Canals--Japan--1830-1840', 'Country life--Japan--1830-1840', 'Villages--Japan--1830-1840', 'Fuji, Mount (Japan)'], 'item_format': ['1 print : woodcut, color.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['Evening glow at Koganei Bridge.']}
# adding 2008660635
# opening loc-item-metadata\jpd-02148.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-02148.json', 'item_id': '2008680291', 'title': '[Hanging poems on a cherry tree]', 'genre': ['Ukiyo-e--Japanese--1740-1750', 'Woodcuts--Japanese--Color--1740-1750--Reproductions--1890-1930'], 'source': 'https://www.loc.gov/item/2008680291/', 'date': '[1741, printed later]', 'place_of_origin': ['Japan'], 'subject': ['Women--Clothing & dress--Japan--1740-1750', 'Beauty--Japan--1740-1750', 'Poetry--1740-1750', 'Cherry trees--Japan--1740-1750', 'Flowers--Japan--1740-1750'], 'item_format': ['1 print : woodcut, color ; 59.3 x 25.3 cm (sheet)'], 'language': ['jpn'], 'contributor': ['Ishikawa, Toyonobu, 1711-1785, artist'], 'rights': 'No known restrictions on publication.', 'alternative_title': 'Not found'}
# adding 2008680291
# opening loc-item-metadata\jpd-02457.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-02457.json', 'item_id': '2008661015', 'title': '[Teahouse at Koishikawa the morning after a snowfall]', 'genre': ['Ukiyo-e--Japanese--Color--1830-1840', 'Woodcuts--Japanese--Color--1830-1840--Reproductions--1890-1940'], 'source': 'https://www.loc.gov/item/2008661015/', 'date': '[between 1890 and 1940]', 'place_of_origin': ['Japan', 'Fuji, Mount (Japan)'], 'subject': ['Snow--Japan--1830-1840', 'Teahouses--Japan--1830-1840', 'Fuji, Mount (Japan)'], 'item_format': ['1 print : woodcut, color.'], 'language': ['jpn'], 'contributor': ['Katsushika, Hokusai, 1760-1849, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': 'Not found'}
# adding 2008661015
# opening loc-item-metadata\jpd-02467.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-02467.json', 'item_id': '2008661025', 'title': '[Sunset across the Ryōgoku Bridge over the Sumida River at Onmayagashi]', 'genre': ['Ukiyo-e--Japanese--Color--1830-1840', 'Woodcuts--Japanese--Color--1830-1840--Reproductions--1890-1940'], 'source': 'https://www.loc.gov/item/2008661025/', 'date': '[between 1890 and 1940]', 'place_of_origin': ['Japan', 'Fuji, Mount (Japan)'], 'subject': ['Ferries--Japan--1830-1840', 'Sunrises & sunsets--1830-1840', 'Bridges--Japan--1830-1840', 'Rivers--Japan--1830-1840', 'Travelers--Japan--1830-1840', 'Fuji, Mount (Japan)'], 'item_format': ['1 print : woodcut, color.'], 'language': ['jpn'], 'contributor': ['Katsushika, Hokusai, 1760-1849, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': 'Not found'}
# adding 2008661025
# opening loc-item-metadata\jpd-02608.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-02608.json', 'item_id': '2002700023', 'title': 'Fūryū genji yuki no nagame', 'genre': ['Ukiyo-e--1850-1860', 'Landscape prints--Japanese--1850-1860', 'Triptychs--Japanese--Color--1850-1860', 'Woodcuts--Japanese--Color--1850-1860'], 'source': 'https://www.loc.gov/item/2002700023/', 'date': '1853.', 'place_of_origin': ['Japan'], 'subject': ['Women--Japan--1850-1860', 'Winter--Japan--1850-1860', 'Snow--Japan--1850-1860'], 'item_format': ['1 print (3 sheets) : woodcut, color ; 36.8 x 76.1 cm (whole image), 36.4 x 25.4 cm (left panel), 36.8 x 25.1 cm (center panel), 36.5 x 25.6 cm (right panel)'], 'language': ['jpn'], 'contributor': ['Utagawa, Kunisada, 1786-1864, artist.', 'Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['A modern version of the Tale of Genji in snow scenes.']}
# adding 2002700023
# opening loc-item-metadata\jpd-02925.json
# created row dictionary: {'item_type': ['still image'], 'date_uploaded': '2024-12-08', 'source_file': 'loc-item-metadata\\jpd-02925.json', 'item_id': '2009631864', 'title': "Shichūhan'ei tanabata matsuri", 'genre': ["Bird's-eye view prints--1850-1860", 'Ukiyo-e--Japanese--Color--1850-1860', 'Woodcuts--Japanese--Color--1850-1860'], 'source': 'https://www.loc.gov/item/2009631864/', 'date': '[1857]', 'place_of_origin': ['Japan--Tokyo', 'Tokyo (Japan)'], 'subject': ['Festivals--Japan--Tokyo--1850-1860', 'Bamboo--Japan--Tokyo--1850-1860', 'Festive decorations--Japan--Tokyo--1850-1860', 'City & town life--Japan--Tokyo--1850-1860', 'Tokyo (Japan)--1850-1860'], 'item_format': ['1 print : woodcut, color ; 36.3 x 24.1 cm.'], 'language': ['jpn'], 'contributor': ['Andō, Hiroshige, 1797-1858, artist.'], 'rights': 'No known restrictions on publication.', 'alternative_title': ['The city flourishing, Tanabata festival.']}
# adding 2009631864
#
#
# --- LOG ---
# wrote collection_items_data.csv
# with 28 items
# 0 errors (info not written)

# %% [markdown]
# ## NYPL Items

# %%
# check for right metadata files
file_count = 0
for file in glob.glob('nypl-item-metadata\\*.json'):
    file_count += 1
    print(file)

print('found', file_count, 'files')
# Out:
# nypl-item-metadata\00121360-c5d2-012f-3258-58d385a7bc34.json
# nypl-item-metadata\0032a710-c5d3-012f-18d7-58d385a7bc34.json
# nypl-item-metadata\005b5350-c5d2-012f-c31b-58d385a7bc34.json
# nypl-item-metadata\007fbda0-c5d3-012f-dd3b-58d385a7bc34.json
# nypl-item-metadata\058cdb20-c5d2-012f-089d-58d385a7bc34.json
# nypl-item-metadata\05c1e9e0-c5d2-012f-a038-58d385a7bc34.json
# nypl-item-metadata\0608ad80-c5d2-012f-7d97-58d385a7bc34.json
# nypl-item-metadata\063b3b00-c5d2-012f-0b79-58d385a7bc34.json
# nypl-item-metadata\06831e40-c5d2-012f-1705-58d385a7bc34.json
# nypl-item-metadata\06a999f0-c5d3-012f-19e0-58d385a7bc34.json
# nypl-item-metadata\06b8ad90-c5d2-012f-5f9e-58d385a7bc34.json
# nypl-item-metadata\06dfc390-c5d3-012f-bbf9-58d385a7bc34.json
# nypl-item-metadata\070969e0-c5d2-012f-a3f2-58d385a7bc34.json
# nypl-item-metadata\072e50a0-c5d3-012f-2ba1-58d385a7bc34.json
# nypl-item-metadata\073c37f0-c5d2-012f-42ca-58d385a7bc34.json
# nypl-item-metadata\07804990-c5d2-012f-8ff7-58d385a7bc34.json
# nypl-item-metadata\07b62880-c5d2-012f-1302-58d385a7bc34.json
# nypl-item-metadata\08001150-c5d2-012f-fb64-58d385a7bc34.json
# nypl-item-metadata\0836e680-c5d2-012f-57f8-58d385a7bc34.json
# nypl-item-metadata\087f9640-c5d2-012f-20bc-58d385a7bc34.json
# nypl-item-metadata\08b7a640-c5d2-012f-257e-58d385a7bc34.json
# nypl-item-metadata\08ee4c20-c5d3-012f-b792-58d385a7bc34.json
# nypl-item-metadata\0904ab50-c5d2-012f-7b5f-58d385a7bc34.json
# nypl-item-metadata\09392820-c5d3-012f-6c21-58d385a7bc34.json
# nypl-item-metadata\09395ea0-c5d2-012f-6a39-58d385a7bc34.json
# nypl-item-metadata\098247f0-c5d2-012f-37d4-58d385a7bc34.json
# nypl-item-metadata\09b732f0-c5d2-012f-4ac4-58d385a7bc34.json
# nypl-item-metadata\09bb9d10-c5d3-012f-41e5-58d385a7bc34.json
# nypl-item-metadata\09eb8530-c5d2-012f-8cd4-58d385a7bc34.json
# nypl-item-metadata\09f3d600-c5d3-012f-775f-58d385a7bc34.json
# nypl-item-metadata\0a2504b0-6b29-013a-70e1-0242ac110004.json
# nypl-item-metadata\0a332130-c5d2-012f-b355-58d385a7bc34.json
# nypl-item-metadata\0a3cf940-c5d3-012f-013f-58d385a7bc34.json
# nypl-item-metadata\0a67ba70-c5d2-012f-6894-58d385a7bc34.json
# nypl-item-metadata\0a7489b0-c5d3-012f-1d20-58d385a7bc34.json
# nypl-item-metadata\0aae9e10-c5d2-012f-12e4-58d385a7bc34.json
# nypl-item-metadata\f3ee86c0-c5d1-012f-9c87-58d385a7bc34.json
# nypl-item-metadata\f434a240-c5d1-012f-3d5e-58d385a7bc34.json
# nypl-item-metadata\f45284e0-c5d2-012f-5bd5-58d385a7bc34.json
# nypl-item-metadata\f467c560-c5d1-012f-d7d2-58d385a7bc34.json
# nypl-item-metadata\f48c6970-c5d2-012f-3244-58d385a7bc34.json
# nypl-item-metadata\f51531b0-c5d2-012f-5cb2-58d385a7bc34.json
# nypl-item-metadata\f54b0810-c5d2-012f-d835-58d385a7bc34.json
# nypl-item-metadata\f594a930-c5d2-012f-61fc-58d385a7bc34.json
# nypl-item-metadata\f5aac120-c5d1-012f-aeef-58d385a7bc34.json
# nypl-item-metadata\f5df2890-c5d1-012f-22c2-58d385a7bc34.json
# nypl-item-metadata\f6aa3670-c5d1-012f-982d-58d385a7bc34.json
# nypl-item-metadata\f7746120-6045-013a-d9b4-0242ac110004.json
# nypl-item-metadata\f8a98840-c5d1-012f-926d-58d385a7bc34.json
# nypl-item-metadata\f926a470-c5d1-012f-20b0-58d385a7bc34.json
# nypl-item-metadata\fa19a590-c5d1-012f-4a41-58d385a7bc34.json
# nypl-item-metadata\fb950a80-c5d1-012f-8ceb-58d385a7bc34.json
# nypl-item-metadata\fc62a0c0-c5d1-012f-a111-58d385a7bc34.json
# nypl-item-metadata\fc917300-c5d2-012f-d85c-58d385a7bc34.json
# nypl-item-metadata\fc9fa600-c5d1-012f-a540-58d385a7bc34.json
# nypl-item-metadata\fceac610-c5d1-012f-0307-58d385a7bc34.json
# nypl-item-metadata\fcf486c0-c5d2-012f-02f5-58d385a7bc34.json
# nypl-item-metadata\fd295c60-c5d2-012f-349a-58d385a7bc34.json
# nypl-item-metadata\fd74dce0-c5d2-012f-97bf-58d385a7bc34.json
# nypl-item-metadata\fda9f7a0-c5d2-012f-1222-58d385a7bc34.json
# nypl-item-metadata\fe00af80-c5d1-012f-69a6-58d385a7bc34.json
# nypl-item-metadata\fe720b70-c5d2-012f-d9b8-58d385a7bc34.json
# nypl-item-metadata\fea4aef0-c5d2-012f-01fb-58d385a7bc34.json
# nypl-item-metadata\feefdd10-c5d2-012f-91f1-58d385a7bc34.json
# nypl-item-metadata\ff191a30-c5d1-012f-087f-58d385a7bc34.json
# nypl-item-metadata\ff3013e0-c5d2-012f-8c0d-58d385a7bc34.json
# nypl-item-metadata\ff79e970-c5d2-012f-46b5-58d385a7bc34.json
# nypl-item-metadata\ff8c57d0-c5d1-012f-85b0-58d385a7bc34.json
# nypl-item-metadata\ffafddf0-c5d2-012f-d8ad-58d385a7bc34.json
# nypl-item-metadata\fff9aec0-c5d2-012f-d9bd-58d385a7bc34.json
# found 693 files

# %%
# add metadata files to list
list_of_nypl_item_metadata_files = list() 
for file in glob.glob('nypl-item-metadata\\*.json'):
    list_of_nypl_item_metadata_files.append(file)

len(list_of_nypl_item_metadata_files)
# Out:
# 693

# %%
# set up the containers to create the csv of all the item fields
# file for csv to read out
file_count = 0
items_written = 0
error_count = 0

# set up a list for the columns in your csv; 
# your goal should be to automate this, but . . . 
# it works for demonstration as you set up the crosswalk
headers = ['item_type', 'date_uploaded', 'source_file', 'item_id', 'title', 'genre', 'source', 'date', 'place_of_origin', 'subject', 'item_format', 'language', 'contributor', 'rights', 'alternative_title']

for file in list_of_nypl_item_metadata_files:
    file_count += 1
    print('opening', file)

    # try first with one file
    with open(file, 'r', encoding='utf-8') as data:
         # load the item data
        try:
            item_data = json.load(data)
            starting_point = item_data['nyplAPI']['response']['mods']
        except:
            print('error loading',file)
            error_count += 1
            continue
        
         # extract/name the data you want
        # item type
        item_type = starting_point['typeOfResource']['$']

        # date uplaoded
        date_uploaded = '2024-12-08'

        # extract the data you want
        # for checking purposes, add in the source of the info
        source_file = str(file)
        source_base_url = 'https://digitalcollections.nypl.org/items/'
        # make sure there's some unique and stable identifier
        item_id = item_data['nyplAPI']['request']['uuid']['$']
        # get all titles
        titles = []
        for title in starting_point['titleInfo']:
            if title == 'title':
                titles.append(starting_point['titleInfo'][title]['$'])
        title = titles
        
        try:
            # get all genres
            genres = []
            for genre in starting_point['genre']:
                genres.append(genre['$'])

            genre = genres
        except:
            try:
                genre = starting_point['genre']['$']
            except:
                genre = 'Not found'
        source = source_base_url + item_data['nyplAPI']['request']['uuid']['$']
        try:
            # get all dates
            dates = []
            for date in starting_point['originInfo']['dateIssued']:
                dates.append(date['$'])
           
            date = dates
        except:
            date = 'Not found'
        try:
            place_of_origin = starting_point['originInfo']['place']['placeTerm']['$']
        except:
            place_of_origin = 'Not found'
        try:
            # get all topics
            topic_dict = dict(enumerate(starting_point['subject']))
            topics = []
            for key in topic_dict:
                for other_key in topic_dict[key]:
                    topics.append(topic_dict[key][other_key]['$'])
            
            subject = topics
        except:
            subject = 'Not found'
        phys_descriptions = []
        try:
            # get all physical descriptions
            phys_desc_dict = dict(enumerate(starting_point['physicalDescription']))
            for key in phys_desc_dict:
                for other_key in phys_desc_dict[key]:
                    phys_descriptions.append(phys_desc_dict[key][other_key]['$'])
            
            item_format = phys_descriptions
        except:
            try:
                phys_keys = []
                for key in starting_point['physicalDescription']:
                    phys_descriptions.append(starting_point['physicalDescription'][key]['$'])
                    
                print(phys_descriptions)
                item_format = phys_descriptions
            except:
                item_format = 'Not found'
        try:
            language = starting_point['titleInfo']['lang']
        except:
            language = 'Not found'
        try:
            contributor = starting_point['name']['namePart']['$']
        except:
            try:
                contributor = starting_point['originInfo']['publisher']['$']
            except:
                contributor = 'Not found'
        try:
            rights = item_data['nyplAPI']['response']['rightsStatement']['$']
        except:
            rights = 'Undetermined'
        
        alternative_title = 'Not found'

        # dictionary for the rows
        row_dict = dict()
        
        # look for the item metadata, assign it to the dictionary; 
        # start with some basic elements likely (already enumerated in the headers list) :
        # source file
        row_dict['item_type'] = item_type
        row_dict['date_uploaded'] = date_uploaded
        row_dict['source_file'] = source_file
        # identifier
        row_dict['item_id'] = item_id
        # title
        row_dict['title'] = title
        # genre
        row_dict['genre'] = genre
        # link
        row_dict['source'] = source
        # date
        row_dict['date'] = date
        # place of origin
        row_dict['place_of_origin'] = place_of_origin
        # subject
        row_dict['subject'] = subject
        # format
        row_dict['item_format'] = item_format
        # language
        row_dict['language'] = language
        # contributor
        row_dict['contributor'] = contributor
        #rights
        row_dict['rights'] = rights 
        # alt title
        row_dict['alternative_title'] = alternative_title
        
        print('created row dictionary:',row_dict)

    # write to the csv
    with open(collection_info_csv, 'a', encoding='utf-8', newline='') as fout:
        writer = csv.DictWriter(fout, fieldnames=headers)
        writer.writerow(row_dict)
        items_written += 1
        print('adding',item_id)

print('\n\n--- LOG ---')
print('wrote',collection_info_csv)
print('with',items_written,'items')
print(error_count,'errors (info not written)')
# Out:
# opening nypl-item-metadata\00121360-c5d2-012f-3258-58d385a7bc34.json
# ['14 x 9 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\00121360-c5d2-012f-3258-58d385a7bc34.json', 'item_id': '00121360-c5d2-012f-3258-58d385a7bc34', 'title': ['Girl with parasol carrying infant on back.'], 'genre': ['Postcards', 'Genre photographs'], 'source': 'https://digitalcollections.nypl.org/items/00121360-c5d2-012f-3258-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Made in Japan', 'subject': ['Japanese', 'Children', 'Parasols', 'Clothing & dress -- Japan', 'Infants'], 'item_format': ['14 x 9 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 00121360-c5d2-012f-3258-58d385a7bc34
# opening nypl-item-metadata\0032a710-c5d3-012f-18d7-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\0032a710-c5d3-012f-18d7-58d385a7bc34.json', 'item_id': '0032a710-c5d3-012f-18d7-58d385a7bc34', 'title': ['Native boutique.'], 'genre': ['Postcards', 'Genre photographs'], 'source': 'https://digitalcollections.nypl.org/items/0032a710-c5d3-012f-18d7-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Ceylon', 'subject': ['Sri Lankans', 'Sri Lanka', 'Produce stands', 'Food vendors'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 0032a710-c5d3-012f-18d7-58d385a7bc34
# opening nypl-item-metadata\005b5350-c5d2-012f-c31b-58d385a7bc34.json
# ['Collotypes', '14 x 9 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\005b5350-c5d2-012f-c31b-58d385a7bc34.json', 'item_id': '005b5350-c5d2-012f-c31b-58d385a7bc34', 'title': ['Maiko tending garden.'], 'genre': ['Postcards', 'Genre photographs'], 'source': 'https://digitalcollections.nypl.org/items/005b5350-c5d2-012f-c31b-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Made in Japan', 'subject': ['Japanese', 'Geishas', 'Kimonos', 'Backyards', 'Teenagers'], 'item_format': ['Collotypes', '14 x 9 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 005b5350-c5d2-012f-c31b-58d385a7bc34
# opening nypl-item-metadata\007fbda0-c5d3-012f-dd3b-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\007fbda0-c5d3-012f-dd3b-58d385a7bc34.json', 'item_id': '007fbda0-c5d3-012f-dd3b-58d385a7bc34', 'title': ['Tea estate coolie lines [i.e., housing accommodations].'], 'genre': ['Postcards', 'Genre photographs'], 'source': 'https://digitalcollections.nypl.org/items/007fbda0-c5d3-012f-dd3b-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Ceylon', 'subject': ['Sri Lankans', 'Sri Lanka', 'Contract laborers', 'Dwellings--Sri Lanka'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 007fbda0-c5d3-012f-dd3b-58d385a7bc34
# opening nypl-item-metadata\058cdb20-c5d2-012f-089d-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\058cdb20-c5d2-012f-089d-58d385a7bc34.json', 'item_id': '058cdb20-c5d2-012f-089d-58d385a7bc34', 'title': ['Hamano-Cho, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/058cdb20-c5d2-012f-089d-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Streets--Japan', 'Utility poles', 'Commercial streets', 'Signs (Notices)', 'City & town life -- Japan'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 058cdb20-c5d2-012f-089d-58d385a7bc34
# opening nypl-item-metadata\05c1e9e0-c5d2-012f-a038-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\05c1e9e0-c5d2-012f-a038-58d385a7bc34.json', 'item_id': '05c1e9e0-c5d2-012f-a038-58d385a7bc34', 'title': ['Front Street Mitsui Bussan Kaisha, Ohura, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/05c1e9e0-c5d2-012f-a038-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Streets--Japan', 'Utility poles', 'Street railroads'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 05c1e9e0-c5d2-012f-a038-58d385a7bc34
# opening nypl-item-metadata\0608ad80-c5d2-012f-7d97-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\0608ad80-c5d2-012f-7d97-58d385a7bc34.json', 'item_id': '0608ad80-c5d2-012f-7d97-58d385a7bc34', 'title': ['Kencho dori, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/0608ad80-c5d2-012f-7d97-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Signs (Notices)', 'Utility poles', 'Commercial streets'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 0608ad80-c5d2-012f-7d97-58d385a7bc34
# opening nypl-item-metadata\063b3b00-c5d2-012f-0b79-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\063b3b00-c5d2-012f-0b79-58d385a7bc34.json', 'item_id': '063b3b00-c5d2-012f-0b79-58d385a7bc34', 'title': ['Wisteria blossoms Daitokuji Temple, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/063b3b00-c5d2-012f-0b79-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Courtyards', 'Teahouses', 'Wisteria'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 063b3b00-c5d2-012f-0b79-58d385a7bc34
# opening nypl-item-metadata\06831e40-c5d2-012f-1705-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\06831e40-c5d2-012f-1705-58d385a7bc34.json', 'item_id': '06831e40-c5d2-012f-1705-58d385a7bc34', 'title': ['Entrance pavilion, Fisheries Exhibition, Nagasaki, Japan'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/06831e40-c5d2-012f-1705-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 's.l.', 'subject': ['Nagasaki-shi (Japan)', 'Exhibition buildings', 'Architecture--Japan'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 06831e40-c5d2-012f-1705-58d385a7bc34
# opening nypl-item-metadata\06a999f0-c5d3-012f-19e0-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\06a999f0-c5d3-012f-19e0-58d385a7bc34.json', 'item_id': '06a999f0-c5d3-012f-19e0-58d385a7bc34', 'title': ['The Perahera, an annual Buddhist procession.  Kandy (Ceylon).'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/06a999f0-c5d3-012f-19e0-58d385a7bc34', 'date': ['1901', '1907'], 'place_of_origin': 'Colombo', 'subject': ['Sri Lankans', 'Sri Lanka', 'Festivals', 'Religious processions', 'Howdahs', 'Elephants'], 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'Colombo Apothecaries Company', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 06a999f0-c5d3-012f-19e0-58d385a7bc34
# opening nypl-item-metadata\06b8ad90-c5d2-012f-5f9e-58d385a7bc34.json
# ['Collotypes', '9 x14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\06b8ad90-c5d2-012f-5f9e-58d385a7bc34.json', 'item_id': '06b8ad90-c5d2-012f-5f9e-58d385a7bc34', 'title': ['Matsubara.  Tea-house Mogi Road Tagami Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/06b8ad90-c5d2-012f-5f9e-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 's.l.', 'subject': ['Nagasaki-shi (Japan)', 'Teahouses', 'Leisure -- Japan', 'Japanese', 'Gutters (Roofs)'], 'item_format': ['Collotypes', '9 x14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 06b8ad90-c5d2-012f-5f9e-58d385a7bc34
# opening nypl-item-metadata\06dfc390-c5d3-012f-bbf9-58d385a7bc34.json
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\06dfc390-c5d3-012f-bbf9-58d385a7bc34.json', 'item_id': '06dfc390-c5d3-012f-bbf9-58d385a7bc34', 'title': ['The golden casket presented by the Burmese pilgrims to the Temple of the Tooth, Kandy, Ceylon.'], 'genre': ['Postcards', 'Group portraits'], 'source': 'https://digitalcollections.nypl.org/items/06dfc390-c5d3-012f-bbf9-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Ceylon', 'subject': 'Not found', 'item_format': ['Collotypes', '9 x 14 cm.', 'Photomechanical prints'], 'language': 'eng', 'contributor': 'Andrée (Firm : Colombo, Sri Lanka)', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 06dfc390-c5d3-012f-bbf9-58d385a7bc34
# opening nypl-item-metadata\070969e0-c5d2-012f-a3f2-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\070969e0-c5d2-012f-a3f2-58d385a7bc34.json', 'item_id': '070969e0-c5d2-012f-a3f2-58d385a7bc34', 'title': ['Umegasaki, Nagasaki.'], 'genre': ['Postcards', 'Cityscapes'], 'source': 'https://digitalcollections.nypl.org/items/070969e0-c5d2-012f-a3f2-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Streets--Japan', 'Roofs', 'Utility poles'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 070969e0-c5d2-012f-a3f2-58d385a7bc34
# opening nypl-item-metadata\072e50a0-c5d3-012f-2ba1-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\072e50a0-c5d3-012f-2ba1-58d385a7bc34.json', 'item_id': '072e50a0-c5d3-012f-2ba1-58d385a7bc34', 'title': ['Native dwelling house.  Ceylon.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/072e50a0-c5d3-012f-2ba1-58d385a7bc34', 'date': ['1901', '1907'], 'place_of_origin': 'Colombo', 'subject': ['Sri Lankans', 'Sri Lanka', 'Dwellings--Sri Lanka', 'Thatched roofs', 'Huts', 'Tropical forests'], 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'Colombo Apothecaries Company', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 072e50a0-c5d3-012f-2ba1-58d385a7bc34
# opening nypl-item-metadata\073c37f0-c5d2-012f-42ca-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\073c37f0-c5d2-012f-42ca-58d385a7bc34.json', 'item_id': '073c37f0-c5d2-012f-42ca-58d385a7bc34', 'title': ['The No. 3, Mitsubishi dock-yard, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/073c37f0-c5d2-012f-42ca-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Boat & ship industry', 'Dry docks'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 073c37f0-c5d2-012f-42ca-58d385a7bc34
# opening nypl-item-metadata\07804990-c5d2-012f-8ff7-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\07804990-c5d2-012f-8ff7-58d385a7bc34.json', 'item_id': '07804990-c5d2-012f-8ff7-58d385a7bc34', 'title': ['Suwa, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/07804990-c5d2-012f-8ff7-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Equestrian statues', 'Gardens', 'Courtyards', 'Shinto shrines--Japan', 'Nagasaki-shi (Japan)'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 07804990-c5d2-012f-8ff7-58d385a7bc34
# opening nypl-item-metadata\07b62880-c5d2-012f-1302-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\07b62880-c5d2-012f-1302-58d385a7bc34.json', 'item_id': '07b62880-c5d2-012f-1302-58d385a7bc34', 'title': ['Bund of Tomachi, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/07b62880-c5d2-012f-1302-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Waterfronts', 'Seas--Japan'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 07b62880-c5d2-012f-1302-58d385a7bc34
# opening nypl-item-metadata\08001150-c5d2-012f-fb64-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\08001150-c5d2-012f-fb64-58d385a7bc34.json', 'item_id': '08001150-c5d2-012f-fb64-58d385a7bc34', 'title': ['General post office, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/08001150-c5d2-012f-fb64-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Made in Japan.', 'subject': ['Nagasaki-shi (Japan)', 'Post offices', 'Barges', 'Coal', 'Flags'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 08001150-c5d2-012f-fb64-58d385a7bc34
# opening nypl-item-metadata\0836e680-c5d2-012f-57f8-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\0836e680-c5d2-012f-57f8-58d385a7bc34.json', 'item_id': '0836e680-c5d2-012f-57f8-58d385a7bc34', 'title': ['The Suwa Shrine, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/0836e680-c5d2-012f-57f8-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan.', 'subject': ['Nagasaki-shi (Japan)', 'Shinto shrines--Japan', 'Stone lanterns'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 0836e680-c5d2-012f-57f8-58d385a7bc34
# opening nypl-item-metadata\087f9640-c5d2-012f-20bc-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\087f9640-c5d2-012f-20bc-58d385a7bc34.json', 'item_id': '087f9640-c5d2-012f-20bc-58d385a7bc34', 'title': ['Cherry blossoms at Karurusu, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/087f9640-c5d2-012f-20bc-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan.', 'subject': ['Nagasaki-shi (Japan)', 'Cherry trees', 'Japanese tea gardens'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 087f9640-c5d2-012f-20bc-58d385a7bc34
# opening nypl-item-metadata\08b7a640-c5d2-012f-257e-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\08b7a640-c5d2-012f-257e-58d385a7bc34.json', 'item_id': '08b7a640-c5d2-012f-257e-58d385a7bc34', 'title': ['Nishihamano-machi, Tetsubashi-dori, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/08b7a640-c5d2-012f-257e-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Made in Japan.', 'subject': ['Nagasaki-shi (Japan)', 'Commercial streets', 'City & town life -- Japan'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 08b7a640-c5d2-012f-257e-58d385a7bc34
# opening nypl-item-metadata\08ee4c20-c5d3-012f-b792-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\08ee4c20-c5d3-012f-b792-58d385a7bc34.json', 'item_id': '08ee4c20-c5d3-012f-b792-58d385a7bc34', 'title': ['Kandyan chiefs.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/08ee4c20-c5d3-012f-b792-58d385a7bc34', 'date': ['1901', '1907'], 'place_of_origin': 's.l.', 'subject': ['Sri Lankans', 'Sri Lanka', 'Tribal chiefs'], 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 08ee4c20-c5d3-012f-b792-58d385a7bc34
# opening nypl-item-metadata\0904ab50-c5d2-012f-7b5f-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\0904ab50-c5d2-012f-7b5f-58d385a7bc34.json', 'item_id': '0904ab50-c5d2-012f-7b5f-58d385a7bc34', 'title': ['Gantry crane at Nagasaki dockyard.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/0904ab50-c5d2-012f-7b5f-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan.', 'subject': ['Nagasaki-shi (Japan)', 'Gantry cranes', 'Hoisting machinery', 'Boat & ship industry'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 0904ab50-c5d2-012f-7b5f-58d385a7bc34
# opening nypl-item-metadata\09392820-c5d3-012f-6c21-58d385a7bc34.json
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\09392820-c5d3-012f-6c21-58d385a7bc34.json', 'item_id': '09392820-c5d3-012f-6c21-58d385a7bc34', 'title': ['Fruit sellers, Colombo.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/09392820-c5d3-012f-6c21-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Not found', 'subject': ['Sri Lankans', 'Sri Lanka', 'Food vendors', 'Street vendors', 'Women', 'Clothing & dress', 'Lifting & carrying'], 'item_format': ['Collotypes', '14 x 9 cm.', 'Photomechanical prints'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 09392820-c5d3-012f-6c21-58d385a7bc34
# opening nypl-item-metadata\09395ea0-c5d2-012f-6a39-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\09395ea0-c5d2-012f-6a39-58d385a7bc34.json', 'item_id': '09395ea0-c5d2-012f-6a39-58d385a7bc34', 'title': ['Shimizu Temple, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/09395ea0-c5d2-012f-6a39-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan.', 'subject': ['Nagasaki-shi (Japan)', 'Roofs', 'Buddhist temples', 'Hills'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 09395ea0-c5d2-012f-6a39-58d385a7bc34
# opening nypl-item-metadata\098247f0-c5d2-012f-37d4-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\098247f0-c5d2-012f-37d4-58d385a7bc34.json', 'item_id': '098247f0-c5d2-012f-37d4-58d385a7bc34', 'title': ['Umegasaki, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/098247f0-c5d2-012f-37d4-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Streets--Japan', 'Roofs', 'Utility poles', 'City & town life'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 098247f0-c5d2-012f-37d4-58d385a7bc34
# opening nypl-item-metadata\09b732f0-c5d2-012f-4ac4-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\09b732f0-c5d2-012f-4ac4-58d385a7bc34.json', 'item_id': '09b732f0-c5d2-012f-4ac4-58d385a7bc34', 'title': ['Bund of Ohura, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/09b732f0-c5d2-012f-4ac4-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Piers & wharves', 'Dories (Boats)', 'Utility poles', 'Waterfronts'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 09b732f0-c5d2-012f-4ac4-58d385a7bc34
# opening nypl-item-metadata\09bb9d10-c5d3-012f-41e5-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\09bb9d10-c5d3-012f-41e5-58d385a7bc34.json', 'item_id': '09bb9d10-c5d3-012f-41e5-58d385a7bc34', 'title': ['Ceylon : Singhalese women'], 'genre': ['Postcards', 'Ethnographic photographs', 'Photographs'], 'source': 'https://digitalcollections.nypl.org/items/09bb9d10-c5d3-012f-41e5-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Not found', 'subject': 'Not found', 'item_format': ['Collotypes', '9 x 14 cm'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 09bb9d10-c5d3-012f-41e5-58d385a7bc34
# opening nypl-item-metadata\09eb8530-c5d2-012f-8cd4-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\09eb8530-c5d2-012f-8cd4-58d385a7bc34.json', 'item_id': '09eb8530-c5d2-012f-8cd4-58d385a7bc34', 'title': ['Bamboo road of Mogi, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/09eb8530-c5d2-012f-8cd4-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Bamboo', 'Dirt roads'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 09eb8530-c5d2-012f-8cd4-58d385a7bc34
# opening nypl-item-metadata\09f3d600-c5d3-012f-775f-58d385a7bc34.json
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\09f3d600-c5d3-012f-775f-58d385a7bc34.json', 'item_id': '09f3d600-c5d3-012f-775f-58d385a7bc34', 'title': ['Cremation of a Buddhist priest.'], 'genre': ['Postcards', 'Group portraits'], 'source': 'https://digitalcollections.nypl.org/items/09f3d600-c5d3-012f-775f-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Ceylon', 'subject': ['Sri Lankans', 'Sri Lanka', 'Funeral rites & ceremonies', 'Cremation'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Photomechanical prints'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 09f3d600-c5d3-012f-775f-58d385a7bc34
# opening nypl-item-metadata\0a2504b0-6b29-013a-70e1-0242ac110004.json
# ['Collotypes', '9 x 14  cm', 'Tinted collotype.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\0a2504b0-6b29-013a-70e1-0242ac110004.json', 'item_id': '0a2504b0-6b29-013a-70e1-0242ac110004', 'title': ['Hongkong'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/0a2504b0-6b29-013a-70e1-0242ac110004', 'date': 'Not found', 'place_of_origin': 'Hong Kong', 'subject': 'Not found', 'item_format': ['Collotypes', '9 x 14  cm', 'Tinted collotype.'], 'language': 'eng', 'contributor': 'Hongkong Pictorial Postcard Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 0a2504b0-6b29-013a-70e1-0242ac110004
# opening nypl-item-metadata\0a332130-c5d2-012f-b355-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\0a332130-c5d2-012f-b355-58d385a7bc34.json', 'item_id': '0a332130-c5d2-012f-b355-58d385a7bc34', 'title': ['Shiomisaki at Mogi, Nagasaki.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/0a332130-c5d2-012f-b355-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Made in Japan', 'subject': ['Nagasaki-shi (Japan)', 'Fishing nets', 'Bays (Bodies of water)', 'Piers & wharves'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 0a332130-c5d2-012f-b355-58d385a7bc34
# opening nypl-item-metadata\0a3cf940-c5d3-012f-013f-58d385a7bc34.json
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\0a3cf940-c5d3-012f-013f-58d385a7bc34.json', 'item_id': '0a3cf940-c5d3-012f-013f-58d385a7bc34', 'title': ['Buddhist priests at their shrine.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/0a3cf940-c5d3-012f-013f-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Ceylon; printed in Germany', 'subject': ['Sri Lankans', 'Sri Lanka', 'Buddhism', 'Buddhist temples', 'Religious articles'], 'item_format': ['Collotypes', '14 x 9 cm.', 'Photomechanical prints'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding 0a3cf940-c5d3-012f-013f-58d385a7bc34
# opening nypl-item-metadata\0a67ba70-c5d2-012f-6894-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Hand colored.']
# ...
# adding fda9f7a0-c5d2-012f-1222-58d385a7bc34
# opening nypl-item-metadata\fe00af80-c5d1-012f-69a6-58d385a7bc34.json
# ['Photomechanical prints', '14 x 9 cm']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\fe00af80-c5d1-012f-69a6-58d385a7bc34.json', 'item_id': 'fe00af80-c5d1-012f-69a6-58d385a7bc34', 'title': ['Japan'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/fe00af80-c5d1-012f-69a6-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Not found', 'subject': ['Japanese', 'Flags', 'Kimonos', 'Fans (Accessories)'], 'item_format': ['Photomechanical prints', '14 x 9 cm'], 'language': 'eng', 'contributor': 'Not found', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding fe00af80-c5d1-012f-69a6-58d385a7bc34
# opening nypl-item-metadata\fe720b70-c5d2-012f-d9b8-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.', 'Halftone collotype.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\fe720b70-c5d2-012f-d9b8-58d385a7bc34.json', 'item_id': 'fe720b70-c5d2-012f-d9b8-58d385a7bc34', 'title': ['Tea pluckers at roadside.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/fe720b70-c5d2-012f-d9b8-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'Ceylon', 'subject': ['Sri Lankans', 'Sri Lanka', 'Tea plantations', 'Agricultural laborers', 'Dirt roads'], 'item_format': ['Collotypes', '9 x 14 cm.', 'Halftone collotype.'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding fe720b70-c5d2-012f-d9b8-58d385a7bc34
# opening nypl-item-metadata\fea4aef0-c5d2-012f-01fb-58d385a7bc34.json
# ['Collotypes', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\fea4aef0-c5d2-012f-01fb-58d385a7bc34.json', 'item_id': 'fea4aef0-c5d2-012f-01fb-58d385a7bc34', 'title': ['Elephant at work on New Estate, Ceylon.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/fea4aef0-c5d2-012f-01fb-58d385a7bc34', 'date': ['1907', '1918'], 'place_of_origin': 'Ceylon', 'subject': ['Sri Lankans', 'Sri Lanka', 'Working elephants', 'Elephants'], 'item_format': ['Collotypes', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'A.W.A. Plâté & Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding fea4aef0-c5d2-012f-01fb-58d385a7bc34
# opening nypl-item-metadata\feefdd10-c5d2-012f-91f1-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\feefdd10-c5d2-012f-91f1-58d385a7bc34.json', 'item_id': 'feefdd10-c5d2-012f-91f1-58d385a7bc34', 'title': ['View on Ceylon tea estate.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/feefdd10-c5d2-012f-91f1-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'London & Detroit; printed in England', 'subject': ['Sri Lankans', 'Sri Lanka', 'Tea plantations', 'Water buffaloes'], 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'Photochrom Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding feefdd10-c5d2-012f-91f1-58d385a7bc34
# opening nypl-item-metadata\ff191a30-c5d1-012f-087f-58d385a7bc34.json
# ['Collotypes', '14 x 9 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\ff191a30-c5d1-012f-087f-58d385a7bc34.json', 'item_id': 'ff191a30-c5d1-012f-087f-58d385a7bc34', 'title': ['Tea server with teapot, cup and serving tray.'], 'genre': ['Postcards', 'Portrait photographs', 'Genre photographs'], 'source': 'https://digitalcollections.nypl.org/items/ff191a30-c5d1-012f-087f-58d385a7bc34', 'date': ['1901', '1907'], 'place_of_origin': 's.l.', 'subject': ['Japanese', 'Clothing & dress -- Japan', 'Kimonos', 'Obi', 'Smiling', 'Tea ceremonies', 'Waitresses'], 'item_format': ['Collotypes', '14 x 9 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding ff191a30-c5d1-012f-087f-58d385a7bc34
# opening nypl-item-metadata\ff3013e0-c5d2-012f-8c0d-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\ff3013e0-c5d2-012f-8c0d-58d385a7bc34.json', 'item_id': 'ff3013e0-c5d2-012f-8c0d-58d385a7bc34', 'title': ['Tea factory, Bunyan Estate, Ceylon.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/ff3013e0-c5d2-012f-8c0d-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'London & Detroit; printed in England', 'subject': 'Not found', 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'Photochrom Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding ff3013e0-c5d2-012f-8c0d-58d385a7bc34
# opening nypl-item-metadata\ff79e970-c5d2-012f-46b5-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\ff79e970-c5d2-012f-46b5-58d385a7bc34.json', 'item_id': 'ff79e970-c5d2-012f-46b5-58d385a7bc34', 'title': ['Roll call.  Dambatenne Estate.  Ceylon.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/ff79e970-c5d2-012f-46b5-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'London & Detroit; printed in England', 'subject': 'Not found', 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'Photochrom Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding ff79e970-c5d2-012f-46b5-58d385a7bc34
# opening nypl-item-metadata\ff8c57d0-c5d1-012f-85b0-58d385a7bc34.json
# ['Collotypes', '14 x 9 cm.', 'Hand colored.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\ff8c57d0-c5d1-012f-85b0-58d385a7bc34.json', 'item_id': 'ff8c57d0-c5d1-012f-85b0-58d385a7bc34', 'title': ['Woman with large parasol carrying child and jar.'], 'genre': ['Postcards', 'Portrait photographs', 'Genre photographs'], 'source': 'https://digitalcollections.nypl.org/items/ff8c57d0-c5d1-012f-85b0-58d385a7bc34', 'date': ['1901', '1909'], 'place_of_origin': 's.l.', 'subject': ['Japanese', 'Parasols', 'Country life', 'Pitchers', 'Rural women', 'Mothers', 'Clothing & dress -- Japan'], 'item_format': ['Collotypes', '14 x 9 cm.', 'Hand colored.'], 'language': 'eng', 'contributor': 's.n.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding ff8c57d0-c5d1-012f-85b0-58d385a7bc34
# opening nypl-item-metadata\ffafddf0-c5d2-012f-d8ad-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\ffafddf0-c5d2-012f-d8ad-58d385a7bc34.json', 'item_id': 'ffafddf0-c5d2-012f-d8ad-58d385a7bc34', 'title': ['Tea in transit to wharf, Ceylon.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/ffafddf0-c5d2-012f-d8ad-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'London & Detroit; printed in England', 'subject': 'Not found', 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'Photochrom Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding ffafddf0-c5d2-012f-d8ad-58d385a7bc34
# opening nypl-item-metadata\fff9aec0-c5d2-012f-d9bd-58d385a7bc34.json
# ['Halftone photomechanical prints', '9 x 14 cm.']
# created row dictionary: {'item_type': 'still image', 'date_uploaded': '2024-12-08', 'source_file': 'nypl-item-metadata\\fff9aec0-c5d2-012f-d9bd-58d385a7bc34.json', 'item_id': 'fff9aec0-c5d2-012f-d9bd-58d385a7bc34', 'title': ['Tea wagons, Ceylon.'], 'genre': 'Postcards', 'source': 'https://digitalcollections.nypl.org/items/fff9aec0-c5d2-012f-d9bd-58d385a7bc34', 'date': 'Not found', 'place_of_origin': 'London & Detroit; printed in England', 'subject': ['Sri Lanka', 'Tea industry', 'Carts & wagons', 'Cattle'], 'item_format': ['Halftone photomechanical prints', '9 x 14 cm.'], 'language': 'eng', 'contributor': 'Photochrom Co.', 'rights': 'The New York Public Library believes that this item is in the public domain under the laws of the United States, but did not make a determination as to its copyright status under the copyright laws of other countries. This item may not be in the public domain under the laws of other countries. Though not required, if you want to credit us as the source, please use the following statement, "From The New York Public Library," and provide a link back to the item on our Digital Collections site. Doing so helps us track how our collection is used and helps justify freely releasing even more content in the future.', 'alternative_title': 'Not found'}
# adding fff9aec0-c5d2-012f-d9bd-58d385a7bc34
#
#
# --- LOG ---
# wrote collection_items_data.csv
# with 693 items
# 0 errors (info not written)
